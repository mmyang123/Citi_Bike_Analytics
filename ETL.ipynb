# %% [markdown]
# ## Tableau Homework 18

# %% [markdown]
# ### Overview
# I am using pandas to aggregate three data tables to clean and transform them before loading the three datasets into Tableau. Each datasets have different record year; would like to join the three of them together to form one dataset.

# %%
import pandas as pd
import numpy as np
import os
import csv

# %% [markdown]
# ## Extract Datasets

# %%
# Loading all the first(year 2020) CSV file

one_citi_bike = pd.read_csv("Resources/2020_citibike_tripdata.csv")

# %%
# Read Citi Bike trip of first file and store into Pandas DataFrames

one_citi_bike_df = pd.DataFrame(one_citi_bike)
one_citi_bike_df.head(10)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1589  2020-03-01 00:00:03.6400  2020-03-01 00:26:32.9860
# 1           389  2020-03-01 00:00:16.7560  2020-03-01 00:06:46.0620
# 2           614  2020-03-01 00:00:20.0580  2020-03-01 00:10:34.2200
# 3           597  2020-03-01 00:00:24.3510  2020-03-01 00:10:22.3390
# 4          1920  2020-03-01 00:00:26.1120  2020-03-01 00:32:26.2680
# 5          2055  2020-03-01 00:00:46.1010  2020-03-01 00:35:01.2880
# 6           764  2020-03-01 00:01:04.6650  2020-03-01 00:13:49.0300
# 7          1719  2020-03-01 00:01:04.9250  2020-03-01 00:29:44.0140
# 8           441  2020-03-01 00:01:09.3050  2020-03-01 00:08:30.8670
# 9           601  2020-03-01 00:01:09.4420  2020-03-01 00:11:11.2240
#
#    start station id             start station name  start station latitude  \
# 0               224          Spruce St & Nassau St               40.711464
# ...

# %%
# Loading the second (year 2021) CSV file

two_citi_bike = pd.read_csv("Resources/2021_citibike_tripdata.csv")
# Out:
# C:\Users\maimy\AppData\Local\Temp\ipykernel_19916\1294316358.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   two_citi_bike = pd.read_csv("Resources/2021_citibike_tripdata.csv")

# %%
# Read Citi Bike trip of second file and store into Pandas DataFrames

two_citi_bike_df = pd.DataFrame(two_citi_bike)
two_citi_bike_df.head(10)
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  4D69477D59E576ED   docked_bike  2021-03-22 18:30:56  2021-03-22 18:37:15
# 1  7F563DA4AC198E0A   docked_bike  2021-03-30 11:47:49  2021-03-30 12:00:40
# 2  C5E0F4FEDA9C2F86   docked_bike  2021-03-04 19:53:50  2021-03-04 20:11:53
# 3  61B726C1884DB04C   docked_bike  2021-03-20 13:05:54  2021-03-20 13:11:16
# 4  7807BB9281BCFD8D   docked_bike  2021-03-20 08:31:09  2021-03-20 08:35:41
# 5  BD0D2E9CB72E76E6   docked_bike  2021-03-29 12:01:47  2021-03-29 12:09:15
# 6  CFF96034AC3E95A4   docked_bike  2021-03-29 16:30:37  2021-03-29 16:52:58
# 7  EC616123D2282A01   docked_bike  2021-03-19 07:43:25  2021-03-19 07:47:05
# 8  B471E5A3513F7DE6   docked_bike  2021-03-02 14:26:59  2021-03-02 14:38:55
# 9  1C19814509B5018C   docked_bike  2021-03-08 22:35:40  2021-03-08 22:42:33
#
#                     start_station_name start_station_id  \
# 0         Willoughby Ave & Wyckoff Ave          5010.02
# ...

# %%
# Loading the third (year 2022) CSV file
three_citi_bike = pd.read_csv("Resources/2022_citibike_tripdata.csv")
# Out:
# C:\Users\maimy\AppData\Local\Temp\ipykernel_19916\1432572518.py:2: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   three_citi_bike = pd.read_csv("Resources/2022_citibike_tripdata.csv")

# %%
# # Read Citi Bike trip of third file and store into Pandas DataFrames

three_citi_bike_df = pd.DataFrame(three_citi_bike)
three_citi_bike_df.head(10)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  DE629683A5C1F9FD  electric_bike  2021-10-09 18:16:26  2021-10-09 18:36:20
# 1  B2914E13F7AD0BE7   classic_bike  2021-10-07 18:16:58  2021-10-07 18:23:42
# 2  226BFE19A144943F   classic_bike  2021-10-29 08:57:28  2021-10-29 09:26:01
# 3  650246D5BC2C2C08   classic_bike  2021-10-20 08:37:39  2021-10-20 08:45:52
# 4  BF6CDCF4CE947A03   classic_bike  2021-10-24 10:20:22  2021-10-24 10:32:12
# 5  B3069B771E97BDDC   classic_bike  2021-10-17 12:36:06  2021-10-17 12:53:57
# 6  B046E7722D59BF41   classic_bike  2021-10-24 14:20:26  2021-10-24 14:26:56
# 7  78533F3754041C79   classic_bike  2021-10-07 10:30:40  2021-10-07 10:48:31
# 8  9F25D89D9DB43B94   classic_bike  2021-10-21 08:12:18  2021-10-21 08:18:16
# 9  61F240ACE44A0C88   classic_bike  2021-10-06 08:20:33  2021-10-06 08:27:26
#
#          start_station_name start_station_id      end_station_name  \
# ...

# %%
# merging three files together

df = pd.concat(
    map(pd.read_csv, ['Resources/2021_citibike_tripdata.csv','Resources/2022_citibike_tripdata.csv']), ignore_index=True)
# Out:
# C:\Users\maimy\AppData\Local\Temp\ipykernel_19916\3662412076.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat(
# C:\Users\maimy\AppData\Local\Temp\ipykernel_19916\3662412076.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat(

# %%
df
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        4D69477D59E576ED    docked_bike  2021-03-22 18:30:56
# 1        7F563DA4AC198E0A    docked_bike  2021-03-30 11:47:49
# 2        C5E0F4FEDA9C2F86    docked_bike  2021-03-04 19:53:50
# 3        61B726C1884DB04C    docked_bike  2021-03-20 13:05:54
# 4        7807BB9281BCFD8D    docked_bike  2021-03-20 08:31:09
# ...                   ...            ...                  ...
# 4600324  C881CC5F60F23500  electric_bike  2021-10-12 11:03:12
# 4600325  FFDD8AA265B1C1D2   classic_bike  2021-10-27 15:24:48
# 4600326  EF4C84FB5CB02D91   classic_bike  2021-10-30 21:23:03
# 4600327  7A3DE386CC5B6876   classic_bike  2021-10-31 16:37:03
# 4600328  7CCA5BC5F10BF7C2   classic_bike  2021-10-11 08:41:40
#
#                     ended_at                   start_station_name  \
# 0        2021-03-22 18:37:15         Willoughby Ave & Wyckoff Ave
# 1        2021-03-30 12:00:40            Franklin Ave & Myrtle Ave
# ...
